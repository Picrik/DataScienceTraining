# %% [markdown]
# source : https://towardsdatascience.com/machine-learning-for-text-classification-using-spacy-in-python-b276b4051a49

# %% [markdown]
# # Librairies import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import base64
import string
import re
from collections import Counter
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.metrics import accuracy_score
from nltk.corpus import stopwords
import string
import re
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# # Data import

# %%
df = pd.read_csv('data/research_paper.csv')
df.head()
# Out:
#                                                Title Conference
# 0  Innovation in Database Management: Computer Sc...       VLDB
# 1  High performance prime field multiplication fo...      ISCAS
# 2  enchanted scissors: a scissor interface for su...   SIGGRAPH
# 3  Detection of channel degradation attack by Int...    INFOCOM
# 4  Pinning a Complex Network through the Betweenn...      ISCAS

# %% [markdown]
# # Data check

# %%
df.isnull().sum()
# Out:
# Title         0
# Conference    0
# dtype: int64

# %% [markdown]
# # Split

# %%
train, test = train_test_split(df, test_size=0.33, random_state=42)
print('Research title sample:', train['Title'].iloc[0])
print('Conference of this paper:', train['Conference'].iloc[0])
print('Training Data Shape:', train.shape)
print('Testing Data Shape:', test.shape)
# Out:
# Research title sample: Cooperating with Smartness: Using Heterogeneous Smart Antennas in Ad-Hoc Networks.
# Conference of this paper: INFOCOM
# Training Data Shape: (1679, 2)
# Testing Data Shape: (828, 2)

# %% [markdown]
# # Plot topics

# %%
fig = plt.figure(figsize=(8,4))
sns.barplot(x = train['Conference'].unique(), y=train['Conference'].value_counts())
plt.show()

# %% [markdown]
# # Spacy

# %%
stopwords = stopwords.words('english')
nlp = spacy.load('en_core_web_sm')

# %%
punctuations = string.punctuation
def cleanup_text(docs, logging=False):
    texts = []
    counter = 1
    for doc in docs:
        if counter % 1000 == 0 and logging:
            print("Processed %d out of %d documents." % (counter, len(docs)))
        counter += 1
        doc = nlp(doc, disable=['parser', 'ner'])
        tokens = [tok.lemma_.lower().strip() for tok in doc if tok.lemma_ != '-PRON-']
        tokens = [tok for tok in tokens if tok not in stopwords and tok not in punctuations]
        tokens = ' '.join(tokens)
        texts.append(tokens)
        print(tokens)
    return pd.Series(texts)

INFO_text = [text for text in train[train['Conference'] == 'INFOCOM']['Title']]
IS_text = [text for text in train[train['Conference'] == 'ISCAS']['Title']]
INFO_clean = cleanup_text(INFO_text)
INFO_clean = ' '.join(INFO_clean).split()
IS_clean = cleanup_text(IS_text)
IS_clean = ' '.join(IS_clean).split()
INFO_counts = Counter(INFO_clean)
IS_counts = Counter(IS_clean)
INFO_common_words = [word[0] for word in INFO_counts.most_common(20)]
INFO_common_counts = [word[1] for word in INFO_counts.most_common(20)]
fig = plt.figure(figsize=(18,6))
sns.barplot(x=INFO_common_words, y=INFO_common_counts)
plt.title('Most Common Words used in the research papers for conference INFOCOM')
plt.show()
# Out:
# cooperate smartness use heterogeneous smart antennas ad hoc networks
# maximize throughput wireless network finite internal buffer
# state dependent proportional fair scheduling algorithms wireless forward link data services
# calms cloud assist live medium streaming globalized demand time region diversity
# cross layer survivability wdm base networks
# topological mai constraints performance wireless cdma sensor networks
# pw mac energy efficient predictive wakeup mac protocol wireless sensor network
# minerva learn infer network path properties
# route overlay multicast networks
# impact sleep schedule aodv convergence time wsn
# heavy tailed g/1-ps queue impatience admission control packet network
# inside new coolstreaming principle measurements performance implications
# deployment optimization sensornet base stochastic location detection system
# assess vulnerability fiber infrastructure disaster
# large scale data collection coordinated approach
# impact power law topology ip level routing dynamic simulation result
# network measurement architecture adaptive applications
# apt accurate outdoor pedestrian tracking smartphone
# statistical approach target count sensor base surveillance system
# approximation algorithms scheduling real time multicast flow wireless lan
# age pseudonyms mobile ad hoc networks
# improve reducetask datum locality sequential mapreduce job
# chain reaction attack 3 g networks analysis defense
# model architecture timing service adaptive policy based management systems
# delay dictionary compression packet network
# almost optimal virtual machine placement traffic intense data center
# communication efficient online detection network wide anomalies
# impact battery degradation optimal management policy harvesting base wireless sensor device
# split flow
# fast replication content distribution overlay
# turbosync clock synchronization shared medium network via principal component analysis miss datum
# spring strategy proof privacy preserve spectrum auction mechanism
# e v efficient visual surveillance electronic footprint
# many many communication new approach collaboration manets
# performance analysis coupling scheduler mapreduce hadoop
# evaluate mobility pattern space route dtn
# potential structure free data aggregation sensor networks
# time step hybrid simulation tshs large scale networks
# distribute querying internet distance information
# coding replication co design interactive multiview video streaming
# game theoretic analysis qos wireless mac
# distribute rate allocation inelastic flow optimization framework optimality condition optimal algorithm
# unified approach optimize performance networks serve heterogeneous flow
# novel method detect bad datum injection attack smart grid
# per flow queueing dynamic queue sharing
# network utilization flow view
# truthful incentive mechanism k anonymity location privacy
# shrink method scaleable performance prediction efficient network simulation
# physical layer security inter session interference large wireless network
# exact regenerating code byzantine fault tolerance distribute storage
# crosspoint queued switch
# approximation algorithms groom optical network design
# exact cooperative regenerating code minimum repair bandwidth distribute storage
# check repeat new method measure dnssec validating resolver
# framework optimal battery management wireless node
# bandwidth allocation virtual path bavp investigation performance classical constrained genetic algorithm base optimisation techniques
# provide throughput differentiation tcp flow use adaptive twocolor marking multi level aqm
# reliable route qos guarantee multi domain ip mpls networks
# edge preserve self healing keep network backbone densely connected
# stable peers existence importance application peer peer live video streaming
# random walk truly memoryless traffic analysis source location privacy random walk
# mobility reduce uncertainty manets
# complex network measurements estimate relevance observed properties
# performance random access scheduling schemes multi hop wireless networks
# optimal mobile association heterogeneous wireless relay network
# maximize lifetime short path aggregation tree wireless sensor network
# inferring link loss use striped unicast probes
# practical routing layer support scalable multihoming
# dynamic game solution malware attack
# optimize energy latency trade sensor networks controlled mobility
# demand oblivious routing distribute vs. centralized approach
# isp egress path selection multihomed networks
# q csma queue length base csma ca algorithms achieving maximum throughput low delay wireless networks
# quantify importance vantage points distribution internet topology measurements
# efficient filter base addressing protocol autoconfiguration mobile ad hoc networks
# packet distribution algorithms sensor networks
# optical label stacking ease trade routing architecture cost optical packet switching
# near optimal multicriteria spanner constructions wireless ad hoc networks
# balance supply demand bandwidth wireless cellular networks utility maximization power rate
# data dissemination bound people centric system
# integrate packet fec adaptive voice playout buffer algorithms internet
# power controlled data prefetching caching wireless packet networks
# packet leash defense wormhole attacks wireless networks
# network emulation testbe dtn application protocol
# tame user generate content mobile network via drop zones
# new ack policy mitigate effect coexist ieee 802.11/802.11e devices
# multi terabit ip switch guaranteed service streaming traffic
# novel analytical model electronic optical switch shared buffer
# speccast
# continuum approach dense wireless network cooperation
# cooperative network coding aware route multi rate wireless networks
# embrace interference ad hoc network use joint routing scheduling multiple packet reception
# queueing analysis disperse periodic messages
# lightweight mutual authentication ownership transfer rfid systems
# classification access network type ethernet wireless lan adsl cable modem dialup
# bargaining towards maximize resource utilization video stream datacenter
# fast packet classification two dimensional conflict free filters
# identify mobile hide behind wireless router
# explanation unexpected 802.11 outdoor link level measurement results
# measurement study internet bottleneck
# towards deep understanding link restoration algorithms mesh networks
# analysis price competition slotted resource allocation game
# efficiency collaborative caching isp aware p2p network
# multiple source multiple destination network tomography
# utility drive spatiotemporal sampling use mobile sensors
# interference alignment multi hop mimo network
# optimization based rate control multicast network coding
# scalable modulation scalable wireless videocast
# bcn expansible network structure data center use hierarchical compound graphs
# deploy mesh node non uniform propagation
# exploit channel memory joint estimation scheduling downlink network
# probabilistic end end delay bounds early deadline first scheduling
# class reliable udp base transport protocol base stochastic approximation
# replica placement qos aware content distribution
# decentralized accurate low cost network bandwidth prediction
# robust boundary detection algorithm base connectivity 3d wireless sensor network
# stackelberg game energy efficient power control wireless network
# maximize restorable throughput mpls networks
# distribute secure load balance skew heterogeneity churn
# harness internet topological stability thorup zwick compact routing
# characterize geospatial dynamic application usage 3 g cellular datum network
# explore cloud passive measurement amazon aws case
# empirical evaluation techniques measuring available bandwidth
# shape segmentation applications sensor networks
# isolate physical per smart rate selection 802.11
# limit sybil attacks structured p2p networks
# reduce packet losses networks commodity ieee 802.15.4 sensor motes use cooperative communication diversity combination
# effective hop hop interest shape mechanism ccn communication
# nanoprotean scalable system software gigabit active router
# maximize capacity power control physical interference model duplex mode
# rss ratio enhance performance rss base application
# channel discontinuity constraint routing wireless networks
# adapcode adaptive network coding code updates wireless sensor networks
# optimal bound online page migration generalize migration cost
# empower network emulator wireless wireline networks
# chaotic maps parsimonious bit error model wireless channels
# slideor online opportunistic network coding wireless mesh networks
# emergence equilibria individual strategy online content diffusion
# fight spam neighborhoodwatch dht
# good effort network modeling performance analysis via large networks asymptotics
# fast pda synchronization use characteristic polynomial interpolation
# general capacity scaling wireless network
# route scheme content based networking
# differentiated multimedia web services use quality aware transcoding
# architecture manage application services global networks
# nature revenue share contract incentivize spectrum sharing
# socially aware network design games
# keep friend close incorporate trust social network base sybil defense
# toward simple criterion establish capacity scale law wireless network
# bound power rate function wireless ad hoc network
# bit stuffing algorithm crosstalk avoidance high speed switching
# evaluation weak state mechanism design indirection dynamic networks
# detection channel degradation attack intermediary node linear networks
# cluster overhead hierarchical routing mobile ad hoc networks
# optimal waveband switching optical ring networks
# efficient regular expression compression algorithm new perspective
# robust geo routing embedding dynamic wireless networks
# provide multiple service classes bursty data traffic cellular networks
# integrate fluid models packet simulation
# technique count dnssec validator
# tunable locally optimal geographical forwarding wireless sensor networks sleep wake cycling node
# ubiquitous datum collection mobile user wireless sensor network
# minimize end end delay novel routing metric multi radio wireless mesh networks
# border games cellular networks
# novel quantitative approach measuring network security
# tractable accurate cross layer model multi hop mimo network
# ultrafast photonic label switch asynchronous packets variable length
# channel assignment dense mc mr wireless network scale law algorithm
# ip fast reroute lightweight via without additional addresses
# zoom multi resolution tasking framework crowdsourced geo spatial sensing
# bi criteria approximation algorithms power efficient low interference topology control unreliable ad hoc networks
# interaction competition innovation service orient internet economic model
# quantitative assured forwarding service
# optimality interconnection valiant load balancing networks
# towards omnidirectional passive human detection
# evaluation use preference clustering large scale multicast application
# hybrid collision control ieee 802.11 ad hoc networks
# security cross layer protocol wireless sensor network
# delay tolerant event collection sensor networks mobile sink
# distributed power control cognitive user access base primary link control feedback
# ego network twitter experimental analysis
# efficient resource allocation flexible channel cooperation ofdma cognitive radio networks
# pricing competition route selfish strategic nodes multi hop relay networks
# packet pacing short buffer optical packet switch networks
# simple sybil proof mechanism multi level marketing
# route fairness chord analysis enhancement
# generic framework throughput optimal control mr mc wireless network
# efficient distribute computation maximum multicast rate
# scalable ip lookup programmable routers
# dynamic guard bandwidth scheme wireless broadband networks
# design practical access point association protocol
# core stateless guarantee rate scheduling algorithms
# explore trade label size stack depth mpls routing
# efficient buffer management policy base integrated fuzzy ga approach
# location privacy protection rss localization system use antenna pattern synthesis
# recognize exponential inter contact time vanets
# qos route performance dependent cost
# argus end end service anomaly detection localization isp 's point view
# spotter model base active geolocation service
# integration streaming elastic traffic wireless networks
# smooth energy consumption peak demand reduction smart grid
# scalable cycle break algorithms gigabit ethernet backbones
# joint effects radio channels node mobility link dynamics wireless networks
# pan scan configuring camera coverage
# wavelength assignment problem multifiber wdm star ring networks
# optimal allocation electronic content
# service capacity peer peer networks
# landmark selection greedy landmark descent route sensor networks
# failure control multipath route tracing
# agnostic topology base spam avoidance large scale web crawl
# dht base traffic localization wild
# origin power laws internet topologies revisit
# analysis blocking probability noise crosstalk impair optical networks
# binary increase congestion control bic fast long distance networks
# resource aware middleware services manets
# proactive failure detection wdm carry ip
# impact mobility multicast capacity wireless networks
# hardness approximation survivable multi level fat tree problem
# adaptive electricity scheduling microgrid
# throughput analysis end end measurement base admission control ip
# fast scalable secret key generation exploit channel phase randomness wireless network
# scan enable fast smooth handoff ap dense 802.11 wireless networks
# understand sub stream scheduling p2p hybrid live streaming systems
# satellite satellite sos network novel architecture satellite network
# swim simple model generate small mobile worlds
# minimum energy broadcast using practical directional antennas wireless networks
# pricing algorithm day ahead electricity market flexible consumer participation
# heuristic algorithms joint configuration optical electrical layer multi hop wavelength routing networks
# pad orthogonality efficient subspace authentication network coding
# delay analysis multi hop wireless networks
# quality triangle inequality violation aware route overlay architecture
# coordination network security game
# alternate hop wait channel rendezvous method cognitive radio network
# distributed construction connected dominating set wireless ad hoc networks
# demand drive service differentiation cluster base network servers
# dipzoom internet measurements marketplace
# network equilibrium heterogeneous congestion control protocol
# simple efficient k coverage verification without location information
# sensor network navigation without locations
# millimeter wave wpan cross layer modeling multi hop architecture
# singlehop collaborative feedback primitive wireless sensor networks
# toward p2p base multimedia sharing user generate content
# self organizing dynamic fractional frequency reuse good effort traffic distribute inter cell coordination
# policy base qos architecture muse
# scheduling mobile ad hoc networks topology channel state uncertainty
# low complexity distribute scheduling algorithms wireless networks
# throughput delay tradeoff large scale manets network coding
# ip fast reroute loop free alternates revisit
# session base overload control qos aware web servers
# optimal configuration ospf aggregates
# throughput delay mobility wireless ad hoc networks
# impact power control performance ad hoc wireless network
# maximum coverage minimum cost multi domain ip mpls networks
# epidemiological modelling peer peer viruses pollution
# fight bufferbloat coexistence aqm low priority congestion control
# meandering current mobility model impact underwater mobile sensor networks
# multi vpn optimization scalable routing via relay
# tp crahn transport protocol cognitive radio ad hoc networks
# locating sensor forest case study greenorbs
# property random direction model
# pulse flexible p2p live streaming system
# trajectory improve data delivery vehicular network
# point cast service wireless networks
# localization 3d surface sensor network challenge solution
# scalable hierarchical access control secure group communications
# load balancing wireless sensor networks use kirchhoff 's voltage law
# impromptu measurement infrastructures use rtp
# measurement base multipath multicast
# consideration size buffers optical packet switch networks
# energy optimal control time vary wireless network
# unified energy efficient routing multi hop wireless networks
# spectrum share rewarding framework co channel hybrid access femtocell network
# optimize topology bluetooth wireless personal area networks
# heterogeneous overlay construction random node selection unstructured p2p networks
# file fragmentation unreliable channel
# resequence delays multipath routing asymptotics simple queueing model
# genealogy information spread microblog galton watson base explicative model
# impact file arrival departures buffer sizing core router
# network performance anomaly detection localization
# dynamic frame sizing algorithm cicq switch 100 throughput
# stochastic ordering internet congestion control application
# quality field reconstruction sensor networks
# optimal isp subscription internet multihoming algorithm design implication analysis
# sample biases ip topology measurements
# data broadcasting seamless channel transition highly demand videos
# exchange pairwise secret efficiently
# worst case tcam rule expansion
# global clock synchronization sensor networks
# provision quality control medium access ultrawideband operate wpans
# minimum camera barrier coverage wireless camera sensor network
# content aware caching traffic management content distribution network
# vulnerability protection distribute consensus base spectrum sensing cognitive radio network
# self configuring information management large scale service overlays
# scalable accurate identification level forwarding paths
# architecture algorithm ieee 802.11-based multi channel wireless mesh network
# certified electronic mail protocol resistant minority malicious third parties
# proportional bandwidth allocation diffserv networks
# maintain approximate minimum steiner tree k center mobile agents sensor network
# bpb novel approach obtain network path characteristics non cooperative environment
# move big datum cloud
# static dynamic analysis internet 's susceptibility faults attacks
# autonomic intrusion detection system base behavioral network engineering
# estimate hop distance arbitrary host pairs
# loop mitigation bloom filter base multicast destination orient approach
# maximize submodular set function connectivity constraint theory application network
# kraft 's inequality scheduling packet switch clos networks
# video share propagation social network measurement modeling analysis
# eclipse attacks overlay network threats defense
# measure availability domain name system
# high performance dictionary base string matching deep packet inspection
# differentiated bandwidth sharing disparate flow size
# fair routing delay tolerant networks
# graph base model disconnected ad hoc networks
# packetostatic deployment massively dense sensor network electrostatic problem
# signal processing view packet sampling anomaly detection
# new analysis framework discrete time queueing systems general stochastic sources
# effectiveness probabilistic packet mark ip traceback denial service attack
# demand qos route protocol mobile ad hoc networks
# double mobility coverage sea surface mobile sensor networks
# griddatabus information centric platform scalable secure resilient phasor data sharing
# energy efficient broadcast multiradio multichannel wireless network
# ddos resilient scheduling counter application layer attacks imperfect detection
# energy efficient scheduling individual packet delay constraints
# connectivity large scale cognitive radio ad hoc networks
# qos aware multicore hash scheduler network application
# streaming code channel burst isolated erasure
# limitations variance time test inference long range dependence
# gossip algorithm design analysis application
# viro scalable robust namespace independent virtual route future network
# dimension obs switch partial wavelength conversion fiber delay lines via mean field model
# bodyt2 throughput time delay performance assurance heterogeneous bsn
# dependency isolation thread base multi tier internet service
# movement assisted sensor deployment
# opportunistic routing congestion diversity wireless multi hop networks
# consort node constrain opportunistic routing wireless mesh network
# cooperative packet caching shortest multipath route mobile ad hoc networks
# shadow prices vs. vickrey prices multipath routing
# throughput analysis multiple access relay channel collision model
# location discovery using data drive statistical error modeling
# differentiate traffic engineering qos provision
# secure crowdsourcing base cooperative pectrum sensing
# mate mpls adaptive traffic engineering
# distribute optimal contention window control elastic traffic wireless lan
# wireless network code decide flip switch
# optimal bandwidth reservation hose model vpn multi path routing
# topology control heterogeneous wireless networks problem solutions
# minimize datum collection latency wireless sensor network multiple mobile element
# markov chain model coarse timescale channel variation 802.16e wireless network
# make large scale deployment rcp practical real networks
# aggregate congestion control distributed multimedia applications
# scheduling algorithms cache pre filling content distribution network
# handle network uncertainty heterogeneous wireless network
# green wave latency capacity efficient sleep scheduling wireless networks
# lateral error recovery application level multicast
# joint optimal scheduling route maximum network throughput
# deft distribute exponentially weighted flow splitting
# experimental study leakage delay trade germanium pmosfets logic circuit
# influence external input oscillatory cellular nonlinear networks dynamic
# tuning elliptic filters tuning biquad
# rapid design prototyping universal soft demapper
# ldpc decoder design ieee 802.15 standard
# new fpn correction method pd storage dual capture cmos image sensor use nonfully deplete pin photodiode
# integrated wireless electronic nose system integrate sensing recognition function
# impact control signal non idealties two phase charge pumps
# 40 nm 1.0mb pipeline 6 sram variation tolerant step word line adaptive data aware write assist
# fast global motion estimation base iteration least square estimation sustained symmetrical structure
# high speed differential resistor ladder converter
# towards gbit programmable decoder ldpc convolutional codes
# real time motion feature extraction image processor employ digital pixel sensor base parallel architecture
# custom gzip decoder dtv application
# fast accurate estimation gain sample time mismatch time interleave adc use chip oscillator
# memory efficient continuous flow fft processor wimax application
# uwb mixer balanced wide band active balun use crossing centertape inductor
# reduced complexity space time frequency model multi channel eeg applications
# psrr bridge tie load pwm class amps
# mmse base design scale offset bp base decode algorithm fast rayleigh fade channel
# compensation iq imbalance transmitter nonlinearitie broadband mimo ofdm
# bifurcation frequency control load resonant dc dc converter
# optimization packet routing use chaotic dynamic
# application two layered tabu search optimal allocation upfc maximize transmission capability
# advanced colluder detection technique osift base hiding code
# reduce size ultra wideband true time delay beam form receiver
# propose avs decoder configuration reconfigurable video coding framework
# design performance analysis ds uwb rake receiver
# visual weighted motion compensation frame interpolation motion vector refinement
# 10gbit 2mw inductorless transimpedance amplifier
# fast reliable switching median filter highly corrupt image impulse noise
# new recursive adaptive beamforme algorithms uniform concentric spherical arrays frequency invariant characteristics
# 2-mite product power law networks
# 0.4v ultra low power uwb cmos lna employ noise cancellation
# robust analytical design equiripple comb fir filter
# design reliable 2&times;vdd 3&times;vdd series parallel charge pump nanoscale cmo
# switched capacitor implementation generalized linear integrate fire neuron
# design methodology inductive power transfer system target high power implantable device
# fault aware dynamic routing algorithm chip network
# single miller compensation use invert current buffer multi stage amplifier
# structural analysis petri net batch processing arc
# hall sensor microsystem continuous gain calibration use fully integrate reference
# jitter error spectrum nrz converter
# fluctuation tolerant read scheme ultrafast dna sequence nanopore device
# delay generation technique fast lock frequency synthesizer
# ku band converter perfect differential pll 0.18um cmo
# performance tpc base stbc code mimo ofdm system imt2000 channel
# universal embed compression engine lcd tv system chip band expansion progressive wavelet coding
# tree structure non uniform filter bank multi standard wireless receivers
# face cluster video use constraint propagation
# sub-100na power management system wireless structure health monitoring application
# analysis convergence behavior complex gaussian kernel lms algorithm
# active bandpass filter use transformer feedback 0.18-&micro;m cmo 802.11a wireless lan
# novel zero dynamics design method application hydraulic turbine governor
# arithmetic module generator algorithm optimization capability
# gpu enable parallel processing image halftoning application
# loss analysis low standby loss quasi resonant flyback converter design
# realization mimo linear discrete time system minimum l sub>2</sub>-sensitivity overflow oscillation
# wireless integrated circuit acquisition electrocorticogram signal
# noise tolerant matchline scheme xor base conditional keeper energy efficient tcam
# new class base early termination method fast motion estimation video coding
# watermarke conjugate ordered dither block truncation coding images
# design modeling chip monolithic transformer patterned ground shield
# reconfigurable clock polarity assignment peak current reduction clock gate circuit
# adaptive speed function level set method move object extraction
# unified quadratic programming approach 3-d mixed mode placement
# live demonstration packet base aer 3gevent cumulative throughput
# fvf base output capacitorless ldo regulator wide load capacitance range
# use qbf increase accuracy sat base debugging
# interactive lecturing technique
# adaptive low high voltage swing cmo driver chip interconnects
# generalization oja 's learning rule non symmetric matrices
# topology design fast convergence network consensus algorithm
# auto reconfigurable dual output sc dc dc regulator sub harmonic fix time control energy harvesting application
# efficient memory architecture jpeg2000 entropy codec
# measure harmonic improve fft base algorithm consider frequency variation
# new low voltage cmo unity gain buffer
# cross scene abnormal event detection
# low power 4-bit interleaved burst sampling adc sub ghz impulse uwb radio
# step response optimization technique low power three stage operational amplifier large capacitive load applications
# decoder low density parity check convolutional code large memory
# 60 ghz meta material wideband antenna fpga giga bite datum transmission
# accurate transformation base timing analysis rc non tree circuit
# integrate four port converter compact efficient hybrid power system
# noise couple due silicon via tsvs 3-d integrated circuit
# datum dependent optimization rom structure
# cellular automata large channel separations
# pmos base double ladder integrate charge pump standard process
# drive sense interface gyroscope base bandpass sigma delta modulator
# multi vth level conversion circuit multi vdd systems
# improve energy efficiency functional unit exploit data dependent latency
# video decoder embed temporal lmmse denoise filter
# efficient decision feedforward equalizer parallelizable architecture
# interference analysis resonant inductive coupled wireless power transfer link
# multiuser detection base grover 's algorithm
# power aware noc router use central forecasting base dynamic virtual channel allocation
# signal modulus design blind source separation via algebraic know modulus algorithm perturbation perspective
# high speed configurable fpga architecture k mean clustering
# thermal aware clock synthesis consider stochastic variation correlation
# shield methodologies presence power ground noise
# 372 ps 64-bit adder use fast pull logic 0.18&micro;m cmo
# low voltage analog power law function generator
# object tracking base rfid coverage visual compensation wireless sensor network
# inductively tune cmos astable multivibrator
# attitude sensing system design wireless micro ball endoscopy
# novel hybrid neuro wavelet system robust speech recognition
# probability distribution blackout complex power networks
# high precision output capacitor free low dropout regulator system chip design
# image convolution use probabilistic mapper usb aer board
# lobe asymmetry base automatic classification brain magnetic resonance image
# active noise cancellation motion artifact pulse oximetry use isobestic wavelength light source
# technique design high entropy chaos base true random bit generator
# hardware implementation double tree scan architecture
# power efficiency calculation class e amplifier nonlinear shunt capacitance
# improve statistical properties number sequences produce pseudorandom generators derive r&eacute;nyi chaotic map
# novel genetic algorithm cell crossover circuit design optimization
# robust wide range supply voltage operation use continuous adaptive size ratio gate
# improved method design variable fractional delay iir digital filter
# novel high speed low power negative voltage level shift low voltage application
# compose well picture mdc multi target total variational approach
# high speed tournament given rotation base qr decomposition architecture mimo receiver
# pulse base amplifier data converter bio potential
# surveillance face hallucination via variable selection manifold learning
# low complexity interpolation architecture soft decision reed solomon decoding
# straightforward approach automatic parking system training recording play back
# sampling clock jitter estimation compensation adc circuit
# sc filter rf conversion wideband image rejection
# computer aid average value modeling fourth order pwm dc dc converters
# novel low complexity lattice filter overflow property close normalized lattice
# poisson aer generator inter spike interval analysis
# uncertainty principle second order lpft
# area efficient shuffling scheme aes implementation fpga
# set value derivative lyapunov method full range cellular neural networks
# compact lumped element model tsv 3d ic
# 11 ghz ugbw op amp feed forward compensation technique
# cyclic vernier time digital converter synthesize 65 nm cmos standard library
# image sensor focal plane polarization sensitivity
# approach implementation noise couple continuous time delta sigma modulator
# analytical experimental study tuning range limitation mm wave cmos lc vcos
# new qr decomposition base recursive frequency estimator multiple sinusoid impulsive noise environment
# controller wind generator increase damping power oscillation
# design 64-bit low energy high performance adder use dynamic feedthrough logic
# particle swarm localization acoustic source presence reverberation
# semiblind receiver base upon multiple constrain subspace mud long code downlink multirate ds cdma system
# protocol level performance analysis anti collision protocol rfid system
# output spectrum analysis buck converter dcm pfm control
# framework fast design space exploration use fuzzy search vlsi compute architecture
# double sample path couple single loop 931;&#916 modulator use noise shape integrate quantizer
# df dice scalable solution soft error tolerant circuit design
# artificial immune system base method spam filtering
# mismatch compensate design techniques packaging induce die stress
# self calibrate multi vco pll scheme leakage capacitive modulation mitigation
# design reversible sequential elements feasibility transistor implementation
# analysis soc architecture mpeg reconfigurable video coding framework
# planar microcoil array apply magnetic bead base lab chip high throughput application
# multi strategy object tracking complex situation video surveillance
# adaptive neuron circuit signal compression
# enhance industry participation iscas circuits systems society
# fine resolution time digital converter 5gs adc
# frame level datum reuse motion compensate temporal filtering
# importance select feature non technical loss identification
# 2.4 ghz reference less wireless receiver 1mbps qpsk demodulation
# direct ddfs fm modulator baseband interpolator
# sigma delta adc dynamic reference accurate temperature voltage sensing
# current mode multiple value adder cryptography processor
# subthreshold leakage reduction comparative study scl cmos design
# improve power delay product scl circuit use source follower output stage
# comparative analysis contrast enhancement algorithm surveillance imaging
# deterministic dem dac performance analysis
# find mode nonlinear oscillation krawczyk moore jones algorithm
# optimized qpsk modulator dvb application
# perturbation analysis subspace base semi blind mimo channel estimation approach
# impact mos threshold voltage mismatch current steering dac ct 931;&#916 modulator
# bi criterion optimization non uniform filter bank acoustic echo cancellation
# new quadrature lc oscillator
# efficient output transition time modeling cmos gate ramp exponential input
# improve h.264 avc video code adaptive coefficient suppression
# digitally control rf passive attenuator 65 nm cmos mobile tv tuner ic
# high performance datum acquisition system irfpa testing
# novel feature extraction algorithm classification bird flight call
# challenge recent advance ir uwb system design
# system analysis energy model radio trigger battery less monolithic wireless sensor receiver
# detection chip temperature gradient use 1.5v low power cmo temperature sensor
# detailed analysis phase adc
# weighted viterbi decode mimo ofdm system linear precoding
# high efficiency architecture escot word level pass concurrent context modeling scheme svc
# precedence effect base far field doa estimation algorithm
# precise area control return zero current steer dac reduce sensitivity clock jitter
# impact nbti pbti power gate sram high k metal gate device
# flexible integer dct architecture hevc
# framework spatio temporal analysis video surveillance
# find minimum interconnect sub array reconfigurable vlsi array
# effective multi standard macroblock prediction vlsi design reconfigurable multimedia system
# code division parallel delta sigma converter probabilistic iterative decoding
# face gender recognition halftoning base adaboost classifier
# single chip audio system delta sigma dac class amplifier
# lock range analysis injection lock frequency divider
# automatic skill acquisition reinforcement learning use connection graph stability centrality
# vlsi architecture fast computation 2-d discrete wavelet transform
# programmable voltage current converter linear voltage control resistor
# design process variation tolerant radio frequency low noise amplifier
# state space model sub threshold sram stability analysis
# high performance pseudo multi core ecc processor gf(2 sup>163</sup
# 0.5v wavelet filter use current mirror
# bifurcation chaos electrostatic vibration energy harvester
# fourth order audio bandwidth 87.5-db sndr sigmadelta modulator mems microphones
# basin attraction periodic solution discretize slide mode control system
# architecture multi slot main memory system 3.2 gbps operation
# adaptive project subgradient method application robust signal processing
# modeling stability continuous time sigma delta modulators
# harmonic control network 2.6 ghz cmos class f power amplifier
# new improved cmos class ab buffer base differential flip voltage follower
# energy scalable margin propagation base analog vlsi support vector machine
# dynamic latch comparator low supply voltage 0.45 v 65-nm cmo
# full differential analog design indirect inverse control law base neural network
# low phase noise lc qvco bottom series coupling capacitor tapping
# system architecture exploration configurable hw sw co design h.264 video decoder
# application frequency response masking technique design novel modify dft filter bank
# architecture integrate low complexity reconfigurability channel filter software defined radio receivers
# analysis digital gain error compensation continuous time cascade sigma delta modulator
# design orthogonal code excitation synthetic aperture imaging ultrasound system
# implementation motion sickness evaluation system base eeg spectrum analysis
# another look retina image scalar quantizer
# encoder architecture throughput 10 gbit sec quasi cyclic ldpc code
# sar adc use single capacitor pulse width analog converter base dac
# true correlated double sampling comparator design time base image sensors
# special property modify dft achieve algorithmic fault tolerance adaptive filters
# low distortion fourth order bandpass delta sigma modulator
# continuous time band pass sigma delta modulator implement 0.35&micro;m bicmos use transmission line
# beamforme mimo receiver reduced hardware complexity
# analysis design lumped element quadrature coupler lossy passive element
# tonality index sigma delta modulators psychoacoustics model based approach
# distribute video code use wavelet
# capacitor free cmos low dropout voltage regulator
# cmos high iip2 mixer multi standard receiver
# mode map optimize mv conjunction base mgs scalable svc avc ippp transcoder
# low power low inaccuracy linearity compensate temperature sensor attachable medical device
# revisit absolutely minimal realization two dimensional digital filters
# experimental validation novel adaptive controller piecewise affine system
# hybrid cmos memristor circuit
# memory efficient layered decoder design early termination ldpc code
# computation unstable limit cycle large scale power system model
# error spectrum shape approach lattice filter roundoff noise reduction
# cmo contact imager locate individual cell
# uwb lna ground penetrating radar
# voltage elevator use mems resonator
# run time programming analog circuit use float gate transistor
# area time efficient cellular non linear networks
# design symmetric square root pulse shaping filters transmitters receiver
# cross regulation suppression control scheme ccm single inductor dual output buck converter order power distributive control
# 0.18-&micro;m cmo squarer circuit non coherent uwb receiver
# integer linear programming method spatial temporal mapping viterbi decoder
# new 10 gbps traffic management algorithm high speed network
# 2-path bandpass sigma delta modulator utilize blue noise path selection
# new lc oscillator topology cmos 0.18&micro;m technology
# noise model indirect feedback sigma delta image sensor
# generic sense hardware real time reconstruction structured analog signal
# low voltage self oscillate class e electronic ballast fluorescent lamp
# object base approach plenoptic video processing
# gate level dual threshold static power optimization methodology gdspom design high speed low power soc application use 90 nm mtcmos technology
# amba ahb bus potocol checker efficient debugging mechanism
# partitioning synthesis hybrid architecture simulator
# improved read write scheme anchorless nems cmos non volatile memory
# low voltage soi cmos dtmos mtcmos circuit technique design optimization low power soc application
# low voltage cmo single end fully differential amplifier programmable gain
# analysis design memoryless interconnect encoding scheme
# parallel architecture ray tracing embed intersection algorithm
# amperometric readout electrode array chip bioelectrochemical sensors
# performance analysis correlation base optical flow algorithm noisy environment
# towards legged chip
# design consideration experimental result continuously tune reconfigurable cmo lna
# multistandard fft processor wireless system chip implementation
# efficient homotopy method easily implement spice
# snr measurement base linearity test adc bist
# 11 bit sub ranging sar adc input signal range twice supply voltage
# hybrid mppt method photovoltaic system via estimation revision method
# 3mw 8-bit radiation harden design dac ultra wide temperature range -180&#176;c 120&#176;c.
# nyquist criterion base design continuous time sigma delta modulator
# early case splitting false path detection improve high level atpg technique
# synchronization multihop ad hoc network use connect dominating set
# bin algorithm accurate computer aid device modeling
# variability aware synthesis wideband low noise amplifiers
# adaptive bandwidth reduction scheme video coding
# 7.5mw 11-bit continuous time sigma delta converter wlan application
# efficient hardware accelerator power grid simulation
# nonlinear class e amplifier case study harmonic balance apply switched circuit
# video noise reduction wavelet domain use temporal decorrelation adaptive thresholding
# analog complex gammatone filter cochlear implant channel
# improve pa efficiency chaos base spread multicarri ds cdma system
# two stage ota design base settling time constraints
# double sample cascade sigma delta modulator topology low oversample ratio
# portable biomarker detection magnetic nanotag
# 10gbase lx4 limit amplifier 0.18 micro;m cmo digital process tunable shunt peaking
# power orient delay budgeting combinational circuit
# 10-bit 200-m digitally calibrate pipeline adc use switching opamp
# real time operating system model system level design environment
# computationally efficient iterative decoding storage system design min sum refine
# disparity map acquisition occlusion handling use warping constraint
# reconfigurable cell array concurrent support multiple radio standard flexible mapping
# continuous time vco assist vco base 931;&#916 modulator 76.6db sndr 10mhz bw
# 0.01%thd 70db psrr single end class use variable hysteresis control headphone amplifiers
# study near consensus complex social network use eigen theory
# cmo variable gain wide bandwidth cmfb free differential current feedback amplifier ultrasound diagnostic application
# analysis performance evaluation digital carrier synchronizer modem applications
# distribute video coding base adaptive binning
# quadrature generation technique frequency multiplication base oscillator
# experimental result wideband spectrum sense use random sample adc 90 nm cmo
# tile base gpu optimization esl full system simulation
# incremetal spatio temporal feature extraction retrieval large video database
# front end amplifier low noise tunable bw gain portable biomedical signal acquisition
# well first tree search approach ml decode mimo system
# power minimization 433-mhz lc vco implantable neural recording system
# 1.25/2.5-gb burst mode clock recovery circuit novel dual bit rate structure 0.18&micro;m cmo
# digital skew adaptive clock scheduling algorithm heterogeneous multiprocessor systems chips mpsocs
# minimax design iir digital filters use sdp relaxation technique
# compact lowpass ladder filters use tapped coils
# clb base detection correction bit flip fault sram base fpgas
# low noise monolithic cmos bio potential detector
# new adaptive subpixel base downsampling scheme use edge detection
# variable increment step base reconfigurable interleaver multimode communication application
# digital frequency clock synthesis architecture signal system perspective current state future direction
# transistor level programmable mos analog ic body bias
# process insensitive modulated clock voltage comparator
# capacitor scale low power design cyclic analog digital converter
# new taxonomy reconfigurable prefix adder
# channel estimation scheme chinese dttb system combat long echo high doppler shift
# fast hash tree generator merkle signature scheme
# enhanced sar adc energy efficiency early reset merged capacitor switching algorithm
# analog implementation snr base gain adaptation denoise
# highly parallel image code many core
# fast low power translation lookaside buffer use hierarchical nand match line
# novel coils topology intended biomedical implants multiple carrier inductive link
# cnn implementation spin filters electronic speckle pattern interferometry applications
# rigorous integration piece wise linear continuous system
# finite switching frequency effect sliding mode control double integrator system
# pipeline dual channel switch capacitor programmable gain amplifier
# 4-kb low power 4-t sram design negative word line gate drive
# implementation cnn base perceptual framework rove robot
# power management architecture fast per core dvf heterogeneous mpsocs
# low power cmos gm c filter wireless receiver application chip automatic tuning system
# analysis power supply gain cmo bandgap reference
# design optimization two motion detection circuit video monitoring system
# time domain gradient detection architecture vlsi analog motion sensor
# education digital analog circuit support computer algebra system
# theory placement numdag relate single sequence sp bsg tree
# modeling verification high speed wire link verilog ams
# mixed technique protect precharged bus differential power analysis attacks
# fully integrate reconfigurable architecture coherent self testing iq adc
# rail rail slew boost pre charge buffer
# 916;&#931 ir uwb radar sub mm ranging capability human body monitoring system
# post placement sti well width adjusting geometric programming device mobility enhancement critical path
# clock datum recovery module 90 nm 10gbps serial link -18db channel attenuation
# improved soft bch decoder one extra error compensation
# local interpolation filter estimation fractional pel displacement vector video coding
# log likelihood ratio algorithm rate compatible modulation
# 27-ghz low power push push lc vco wide tuning range 65 nm cmo
# cmos image sensor focal plane spiht image compression
# efficient passive transmission line macromodele algorithm use method characteristic
# dual mode low power low noise 0.18&micro;m cmos front end optical biosensor
# volume power optimize high performance system uav collision avoidance
# synchronization phase synthesis use pll neural network
# snr base frame level video bit rate allocation
# scalable offset cancel current voltage sense amplifier
# time slide suboptimal regulation bilinear interconnect system
# wireless esophageal catheter dedicated respiratory disease diagnostic
# approach joint blind space time equalization doa estimation
# broadband capacitive sensor cmos interface circuit dielectric spectroscopy
# highly efficient method extract fsm flatten gate level netlist
# 7-decades tunable translinear sige bicmos 3-phase sinusoidal oscillator
# line lossless mocap data compression
# novel sigma delta fractional n synthesizer architecture fractional spur quantization noise cancellation
# analytical transient response propagation delay model nanoscale cmos inverter
# multi clock pipeline structure 802.11 wlan transceiver
# mode dependent deblocke filter video coding
# validation statistical non linear model gaas hemt mmic 's hypothesis testing principal component analysis
# proportionate affine projection algorithm basis pursuit perspective
# generalize arbitrary resizing video transcoding
# efficient method estimation autoregressive signals subject colored noise
# emi reduction resonant clock distribution network
# 3.5-d integration case study
# fast 3d bsg algorithm 3d pack problem
# hopf type intermediate scale bifurcation single stage power factor correction power supplies
# 2.4&micro;w wake receiver wireless sensor node -71dbm sensitivity
# document classification use nonnegative matrix factorization underapproximation
# intelligent cage remotely power freely move animal telemetry system
# actionview movement analysis ambulatory monitor elderly homecare systems
# use joint diagonalization blind signal processing
# case study gpu base implementation sequence pair base floorplanning use cuda
# novel truncate squarer linear compensation function
# rethink fourier 's legacy signal system education
# tile interleaving multi level 2-d discrete wavelet transform
# detection method nasalised vowel base acoustic parameter derive phase spectrum
# efficient vlsi design bi cubic convolution interpolation digital image processing
# capacitor free cmos low dropout regulator
# extendable point multi point protocol processor 10g epon mac socs
# accurate transient response model automatic synthesis high speed operational amplifier
# memory efficient scalable video encoder architecture multi source digital home environment
# analog front end rx design uwb impulse radio 90 nm cmo
# group event detection video surveillance
# reconfigurable ic wireless monitoring chemical electrical neural activity
# extended kalman filter algorithm carrier synchronization implementation
# merged first second stage low power pipeline adc
# compress compound image h.264 mpeg-4 avc fully exploit spatial correlation
# low power binary addition use carry increment adder
# two stage series base neural network approach nonlinear independent component analysis
# wavelet base detection move tree branch leave video
# computation communication spike event code programmable analog array
# 1.2v 130&micro;a 10-bit mos log domain sigma delta modulator
# object segmentation wide baseline video
# wide bandwidth sige broadband amplifier 100 gb ethernet applications
# dynamic partial reconfigurable fft ifft prune ofdm base cognitive radio
# 1-v 100-db dynamic range 24.4-khz bandwidth delta sigma modulator
# gpu powered artificial immune system visual application
# efficient multidimensional sampling scheme fouri transform estimation
# task bind base branch bind algorithm noc mapping
# adaptation method fir pre emphasis filter backplane channel
# output characteristics class e amplifier nonlinear shunt capacitance versus supply voltage
# operation class de amplifier outside optimum condition
# micropower comparator high power efficiency hearing aid class amplifier
# model orientation selectivity use neuromorphic multi chip system
# adder circuit transistor use independently control gates
# battery aware variable voltage scheduling real time multiprocessor platforms
# improve hybrid coding scheme intra 4&times;4 residual block produce h.264 avc
# clock distribution model 3-d integrated system
# split adc digital background correction open loop residue amplifier nonlinearity errors 14b pipeline adc
# semi symbolic modeling simulation circuit system
# low power ldpc decode base iteration prediction
# multi hysteresis vccs application multi scroll chaotic oscillators
# pixel level image fusion scheme base linear algebra
# optimal rate allocation scalable video multicast wimax
# stack memory design low cost instruction fold java processor
# simulation technique noise analysis pll design process
# new frame recompression algorithm integrated h.264 video compression
# high pf ultra low thd power factor correction controller sinusoidal wave synthesis optimize thd control
# design robust h sup>&#8734;</sup filter markovian jump system time vary delay parametric uncertainty
# fast algorithm power grid analysis base effective resistance
# distribution relative phase complex wavelet coefficient
# test application time minimization ras use basis optimization column decoder
# multiple sub pixel interpolation filter adaptive symmetry high resolution video coding
# low voltage high linear programmable triode transconductor
# design digital iir integrator use discrete hartley transform interpolation method
# tree structure linear phase nyquist fir filter interpolator decimator
# casl hypervisor virtualization platform
# mixed domain receiver architecture white space software define radio scenario
# improved sar controller dll application
# prediction base adaptive transform coefficient scan inter frame video coding
# novel cmo current mode fully differential tanh x implementation
# reconfigurable mac architecture implement mix vt standard cell library
# non delaunay hierarchical mesh base motion estimation compensation wavelet video coding
# multi layer base rate control algorithm hevc
# integration time optimization integrate photosensor
# vitro epileptic seizure prediction microsystem
# pin complex network betweenness centrality strategy
# turnus design exploration framework dataflow system design
# distributed amplifier base dispersive delay line
# mixed signal implementation nonlinear decoder delta sigma encoded stream
# fast mode selection reduce encode complexity h.264 avc
# review magnetic cellular automata system
# unconstrained regularize 8467;p norm base algorithm reconstruction sparse signal
# analysis propagation delay 3 stack dram
# wavelet base spatially adaptive method despeckle sar image
# low complexity decision direct method carrier frequency offset estimation ieee 802.11ad
# cartesian feedback feedforward transmitter
# localized statistical 3d thermal analysis considering electro thermal coupling
# mesh star hybrid noc architecture cdma switch
# det ff topology detailed investigation energy delay area domain
# sat base atpg path delay faults sequential circuits
# efficient mfcc extraction method speech recognition
# effect accuracy performance digital predistortion rf power amplifier
# cmos linear voltage current dual mode imager
# lut base mpgas fast turnaround time conversion flow
# digital rf processing techniques device mismatch tolerant transmitters nanometer scale cmo
# broadband beamfoming use nested planar arrays 3d fir frustum filter
# content aware write reduction mechanism phase change ram base frame store h.264 video codec system
# retargete methodology nano watt cmos reference circuit base advanced compact mosfet model
# 5.2 pj pulse impulse radio pulse generator 90 nm cmo
# balun lna continuously controllable gain noise distortion cancellation
# l shape segmentation motion compensate prediction h.264
# vlsi decode architecture improved convergence speed reduce decode latency irregular ldpc code wimax
# roesser model realization mimo n system elementary operation
# analysis design loss free resistor base boost converter pwm operation
# model parameter estimation h.264 avc rate control
# high level specification embed listener monitoring network chips
# scheduling bind low gate leakage nanocmos datapath circuit synthesis
# eigenvalue formulation determine initial condition induction machine dynamic power system simulation
# adaptive block size phase correlation motion estimation use adaptive early search termination technique
# mlc stt ram design consider probabilistic asymmetric mtj switching
# new construction algorithm visual crytography gray level image
# pulse width position modulation fully digital audio amplifier
# efficient identification algorithm fir filter noisy data
# efficient prony 's method time vary power system harmonic estimation
# speech recogniton system base structure equivalent fuzzy rbf neural network
# novel polynomial selection scheme low complexity chase algebraic soft decision reed solomon decoding
# novel ray space base color correction algorithm multi view video
# stimulation recording neural tissue close loop artifact
# parallel architecture hermitian decoders satisfy resource throughput constraints
# novel low power physical design methodology mtcmos
# non causal error control wireless video streaming noncoherent signaling
# novel approach statistical simulation ics affect non linear variability
# uncoded ber comparison dfe sccp ofdm use convex analysis framework
# robust prml read channel digital timing recovery multi format optical disc
# semi blind data selective algorithm channel equalization
# feature memristor emulator base artificial neural synapsis
# fast hevc intra mode decision use match edge detector kernel density estimation alike histogram generation
# per survivor processing viterbi decoder bluetooth application
# towards comprehensive systematic classification hardware trojan
# 10-bit 2ghz current steering cmo converter
# model dynamic stability srams presence single event upset seus
# alias locked loop frequency synthesis architecture
# high resolution high accuracy r-2r dac base ordered element matching
# symmetry aware analog layout placement design handle substrate share constraint
# analytical design equiripple dc notch fir filter
# design massively parallel vision processor base multi simd architecture
# super resolution technique thermography dual camera system
# topology identification uncertain general complex dynamical network
# high performance prime field multiplication gpu
# digital filter design optimization use partial cost function
# novel mux ff circuit low power high speed serial link interface
# hardware efficient filterbank design fast recursive mdst imdst algorithm
# program algorithm multilevel phase change memory
# integrated switching power converter hybrid pulse train pwm control
# zf dfe transceiver time vary mimo channel channel independent temporal precoder
# multiparametric biosensor array chip cell culture feedback control microfluidic
# frm base fir filters minimum coefficient sensitivities
# reconfigurable fir filter design use dynamic partial reconfiguration
# novel neural network base linearization auto compensation technique sensor
# design analysis skewed distribution scan chain partition improved test datum compression
# feasibility study fpga base equalizer 112-gbit optical fiber receiver
# normal flow measurement visual motion sensor
# synthesis polynomial base nonlinear device harmonic shifting technique virtual bass system
# static force measurement piezoelectric sensor
# 20-ms sigma delta modulator 802.11a application
# sram hold operation model interaction soft error switch power supply noise
# design grid multi wing butterfly chaotic attractor piecewise l&uuml system base switch control heteroclinic orbit
# area efficient digital amplitude modulator 90 nm cmo
# precompensation algorithm pwm base digital audio amplifiers portable applications
# single inductor multiple output converter adaptive delta current mode control
# complexity reduction polyphase linear phase fir filter symmetric coefficient implementation
# level converting scan flip flops
# signal perturbation free semi blind mrt mimo channel estimation approach
# simple circuit base solution problem residential load participation demand response
# datum reuse method heterogeneous partitions drhp h.264 avc motion compensator
# novel fisher discriminant biometric recognition 2dpca plus 2dfld
# line base image code use adaptive prediction filter
# non iterative high speed division computation base mitchell logarithmic method
# enhanced switching policy buck derive multi level switching power amplifier
# multi chain encoding scheme low cost ate
# ladder network delay model couple interconnect
# estimation capacitive crosstalk induce short circuit energy
# 3.7mw 1.6v cmos analog adaptive equalizer 125mbps wire line transceiver
# compass tilt compensation algorithm use cordic
# codesign synthesis mpeg-4 decoder dataflow description
# efficient data transfer technique vlsi architecture dwt block coder integration jpeg2000 encoder
# pvt invariant single differential datum converter minimum skew duty ratio distortion
# 13-bit low power compact adc suitable sensor application
# 3d stack multi core architecture wideio distribute cache
# streaming implementation zlib decoder algorithm fpga
# auditory speech processing scale shift covariance evaluation automatic speech recognition
# new normalized minimum error entropy algorithm reduced computational complexity
# separation weak reflection single superimpose image use gradient profile sharpness
# optimal signal discrimination low signal noise ratio environment
# perfect shuffling cycle efficient puncturer interleaver software define radio
# compact power efficient cmos exponential voltage voltage converter
# segment specific object base logo detection
# dna like learning algorithm cnn template implementing boolean functions

# %%
IS_common_words = [word[0] for word in IS_counts.most_common(20)]
IS_common_counts = [word[1] for word in IS_counts.most_common(20)]
fig = plt.figure(figsize=(18,6))
sns.barplot(x=IS_common_words, y=IS_common_counts)
plt.title('Most Common Words used in the research papers for conference ISCAS')
plt.show()

# %% [markdown]
# # Machine Learning

# %%
STOPLIST = set(stopwords + list(ENGLISH_STOP_WORDS))
SYMBOLS = " ".join(string.punctuation).split(" ") + ["-", "...", "”", "”"]
class CleanTextTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        return [cleanText(text) for text in X]   
    def fit(self, X, y=None, **fit_params):
        return self
    def get_params(self, deep=True):
        return {}
    
def cleanText(text):
    text = text.strip().replace("\n", " ").replace("\r", " ")
    text = text.lower()
    return text
def tokenizeText(sample):
    tokens = parser(sample)
    lemmas = []
    for tok in tokens:
        lemmas.append(tok.lemma_.lower().strip() if tok.lemma_ != "-PRON-" else tok.lower_)
    tokens = lemmas
    tokens = [tok for tok in tokens if tok not in STOPLIST]
    tokens = [tok for tok in tokens if tok not in SYMBOLS]
    return tokens

# %%
def printNMostInformative(vectorizer, clf, N):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    topClass1 = coefs_with_fns[:N]
    topClass2 = coefs_with_fns[:-(N + 1):-1]
    print("Class 1 best: ")
    for feat in topClass1:
        print(feat)
    print("Class 2 best: ")
    for feat in topClass2:
        print(feat)
        
vectorizer = CountVectorizer(tokenizer=tokenizeText, ngram_range=(1,1))
clf = LinearSVC()

pipe = Pipeline([('cleanText', CleanTextTransformer()), ('vectorizer', vectorizer), ('clf', clf)])
# data
train1 = train['Title'].tolist()
labelsTrain1 = train['Conference'].tolist()
test1 = test['Title'].tolist()
labelsTest1 = test['Conference'].tolist()
# train
pipe.fit(train1, labelsTrain1)# test
preds = pipe.predict(test1)
print("accuracy:", accuracy_score(labelsTest1, preds))
print("Top 10 features used to predict: ")

printNMostInformative(vectorizer, clf, 10)
pipe = Pipeline([('cleanText', CleanTextTransformer()), ('vectorizer', vectorizer)])
transform = pipe.fit_transform(train1, labelsTrain1)
vocab = vectorizer.get_feature_names()
for i in range(len(train1)):
    s = ""
    indexIntoVocab = transform.indices[transform.indptr[i]:transform.indptr[i+1]]
    numOccurences = transform.data[transform.indptr[i]:transform.indptr[i+1]]
    for idx, num in zip(indexIntoVocab, numOccurences):
        s += str((vocab[idx], num))
# Out:
#   File "<ipython-input-23-46cc1f569d4c>", line 18
#     train1 = train['Title'].tolist()
#     ^
# SyntaxError: invalid syntax

# %%
from sklearn import metrics
print(metrics.classification_report(labelsTest1, preds, 
                                    target_names=df['Conference'].unique()))
# Out:
#               precision    recall  f1-score   support
#
#         VLDB       0.75      0.77      0.76       159
#        ISCAS       0.91      0.83      0.87       299
#     SIGGRAPH       0.67      0.66      0.66       106
#      INFOCOM       0.61      0.69      0.65       139
#          WWW       0.62      0.62      0.62       125
#
#     accuracy                           0.74       828
#    macro avg       0.71      0.72      0.71       828
# weighted avg       0.75      0.74      0.75       828
